# %% [markdown]
# ![](../CintillaTecNM-ITD.png)
#
# <div style = "Text-align: center">
#     <h2> Análisis de datos masivos</h2>
#     <h3> Introduccion a Dataframes </h3><br>
#     <h3> Nombre docente </h3>
#     <h4> Jose Gabriel Rodriguez Rivas<h4>
#     <h3> Nombre Alumno </h3>
#     <h4> Misael Omar Vargas Ochoa <h4>
# </div>

# %% [markdown]
# ## Parte 1: Importación de paquetes de Python

# %%
# Code cell 1
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium # Code cell 1

# %% [markdown]
# ## Parte 2: Carga de datos
# ### Paso 1: Cargar los datos delitos en San Francisco en un marco de datos

# %%
# code cell 2
# This should be a local path
dataset_path = 'Data/Map-Crime_Incidents-Previous_Three_Months.csv'

# read the original dataset (in comma separated values format) into a DataFrame
SF = pd.read_csv(dataset_path)

# code cell 3
# !head -n 5 ./Map-Crime_Incidents-Previous_Three_Months.csv

# %% [markdown]
# ### Paso 2: Ver los datos importados

# %%
# Code cell 4
pd.set_option('display.max_rows', 10) #Visualize 10 rows 
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# 0        Sunday  08/31/2014 07:00:00 AM +0000  20:30     CENTRAL
# 1        Sunday  08/31/2014 07:00:00 AM +0000  14:30     CENTRAL
# 2        Sunday  08/31/2014 07:00:00 AM +0000  11:30     CENTRAL
# 3        Sunday  08/31/2014 07:00:00 AM +0000  17:49     MISSION
# 4        Sunday  08/31/2014 07:00:00 AM +0000  18:05    NORTHERN
# ...         ...                           ...    ...         ...
# 30755    Sunday  06/01/2014 07:00:00 AM +0000  15:30    SOUTHERN
# 30756    Sunday  06/01/2014 07:00:00 AM +0000  16:00    NORTHERN
# 30757    Sunday  06/01/2014 07:00:00 AM +0000  15:00  TENDERLOIN
# 30758    Sunday  06/01/2014 07:00:00 AM +0000  15:20     CENTRAL
# 30759    Sunday  06/01/2014 07:00:00 AM +0000  13:15   INGLESIDE
#
#            Resolution                   Address           X          Y  \
# 0                NONE   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# 1                NONE  COLUMBUS AV / JACKSON ST -122.404418  37.796302
# 2                NONE   SUTTER ST / STOCKTON ST -122.406959  37.789435
# 3      ARREST, BOOKED      16TH ST / MISSION ST -122.419672  37.765050
# 4      ARREST, BOOKED   LARKIN ST / OFARRELL ST -122.417904  37.785167
# ...               ...                       ...         ...        ...
# 30755  ARREST, BOOKED  900.0 Block of MARKET ST -122.408052  37.783957
# 30756   ARREST, CITED   POLK ST / MCALLISTER ST -122.418601  37.780261
# 30757   ARREST, CITED     0.0 Block of JONES ST -122.412122  37.781379
# 30758            NONE   200.0 Block of GEARY ST -122.407434  37.787494
# 30759   ARREST, CITED  MISSION ST / BOSWORTH ST -122.426391  37.733675
#
#                                     Location
# 0      (37.7909741243888, -122.417392830334)
# 1      (37.7963018736036, -122.404417620748)
# 2      (37.7894347630337, -122.406958660602)
# 3      (37.7650501214965, -122.419671780296)
# 4      (37.7851670875814, -122.417903977564)
# ...                                      ...
# 30755  (37.7839574642528, -122.408051765969)
# 30756  (37.7802607511488, -122.418600974625)
# 30757  (37.7813786419025, -122.412121608136)
# 30758  (37.7874944447786, -122.407434204569)
# 30759  (37.7336749150401, -122.426391018521)
#
# [30760 rows x 12 columns]

# %%
# Code cell 5
SF.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location'],
#       dtype='object')

# %% [markdown]
# ### ¿Cuántas variables se incluyen en el marco de datos de SF (ignore el índice)?
# #### Respuesta 11

# %%
# Code cell 6
len(SF)
# Out:
# 30760

# %% [markdown]
# ## Parte 3: Preparación de datos
# ### Paso 1: Extraer el mes y el día del campo de Date (Fecha)

# %%
# Code cell 7
SF['Month'] = SF['Date'].apply(lambda row: int(row[0:2]))
SF['Day'] = SF['Date'].apply(lambda row: int(row[3:5]))

# Code cell 8
print(SF['Month'][0:2])
print(SF['Day'][0:2])
# Out:
# 0    8
# 1    8
# Name: Month, dtype: int64
# 0    31
# 1    31
# Name: Day, dtype: int64

# %%
# Code cell 9
print(type(SF['Month'][0]))
# Out:
# <class 'numpy.int64'>

# %% [markdown]
# ### Paso 2: Eliminar las variables del marco de datos de SF

# %%
# Code cell 10
# del SF['IncidntNum']

# Code cell 11
#SF.drop('Location', axis=1, inplace=True )

# Code cell 12
SF.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'Month',
#        'Day'],
#       dtype='object')

# %% [markdown]
# ## Parte 4: Análisis de datos
# ### Paso 1: Resumir las variables para obtener información estadística

# %%
# Code cell 13
CountCategory = SF['Category'].value_counts()
print(CountCategory)
# Out:
# LARCENY/THEFT              8205
# OTHER OFFENSES             4004
# NON-CRIMINAL               3653
# ASSAULT                    2518
# VEHICLE THEFT              1885
#                            ...
# LOITERING                     5
# BAD CHECKS                    3
# GAMBLING                      1
# BRIBERY                       1
# PORNOGRAPHY/OBSCENE MAT       1
# Name: Category, Length: 36, dtype: int64

# %%
# Code cell 14
SF['Category'].value_counts(ascending=True)
# Out:
# PORNOGRAPHY/OBSCENE MAT       1
# BRIBERY                       1
# GAMBLING                      1
# BAD CHECKS                    3
# LOITERING                     5
#                            ...
# VEHICLE THEFT              1885
# ASSAULT                    2518
# NON-CRIMINAL               3653
# OTHER OFFENSES             4004
# LARCENY/THEFT              8205
# Name: Category, Length: 36, dtype: int64

# %% [markdown]
# ### ¿Qué tipo de delitos se cometió más?
# #### Respuesta LARCENY/THEFT

# %%
# Code cell 15
print(SF['Category'].value_counts(ascending=True))
# Out:
# PORNOGRAPHY/OBSCENE MAT       1
# BRIBERY                       1
# GAMBLING                      1
# BAD CHECKS                    3
# LOITERING                     5
#                            ...
# VEHICLE THEFT              1885
# ASSAULT                    2518
# NON-CRIMINAL               3653
# OTHER OFFENSES             4004
# LARCENY/THEFT              8205
# Name: Category, Length: 36, dtype: int64

# %% [markdown]
# ### ¿Qué PdDistrict presentaba la mayoría de los incidentes de delitos informados? Proporcione los comandos de Python utilizados para respaldar su respuesta.
#
# #### Respuesta: SOUTHERN 6185
# #### Comando: print(SF['PdDistrict'].value_counts())

# %%
print(SF['PdDistrict'].value_counts())
# Out:
# SOUTHERN      6185
# MISSION       4011
# CENTRAL       3867
# NORTHERN      3205
# BAYVIEW       2970
# INGLESIDE     2613
# TENDERLOIN    2449
# TARAVAL       2038
# PARK          1800
# RICHMOND      1622
# Name: PdDistrict, dtype: int64

# %% [markdown]
# ### Paso 2: Crear subconjuntos de datos y organizarlos en marcos de datos más pequeños

# %%
# Code cell 16
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimes
# Out:
#       IncidntNum                     Category  \
# 0            NaN                LARCENY/THEFT
# 1            NaN                LARCENY/THEFT
# 2            NaN                LARCENY/THEFT
# 3            NaN                DRUG/NARCOTIC
# 4            NaN                DRUG/NARCOTIC
# ...          ...                          ...
# 9715         NaN                 NON-CRIMINAL
# 9716         NaN               OTHER OFFENSES
# 9717         NaN                      ASSAULT
# 9718         NaN  DRIVING UNDER THE INFLUENCE
# 9719         NaN       SEX OFFENSES, FORCIBLE
#
#                                           Descript DayOfWeek  \
# 0                   GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 2                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 3                   POSSESSION OF METH-AMPHETAMINE    Sunday
# 4                            POSSESSION OF COCAINE    Sunday
# ...                                            ...       ...
# 9715                  AIDED CASE, MENTAL DISTURBED    Friday
# 9716                   MISCELLANEOUS INVESTIGATION    Friday
# 9717                          THREATS AGAINST LIFE    Friday
# 9718  DRIVING WHILE UNDER THE INFLUENCE OF ALCOHOL    Friday
# 9719             ASSAULT TO RAPE WITH BODILY FORCE    Friday
#
#                               Date   Time PdDistrict      Resolution  \
# 0     08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1     08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2     08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3     08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4     08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
# ...                            ...    ...        ...             ...
# 9715  08/01/2014 07:00:00 AM +0000  19:55    MISSION            NONE
# 9716  08/01/2014 07:00:00 AM +0000  22:47   RICHMOND            NONE
# 9717  08/01/2014 07:00:00 AM +0000  23:55    BAYVIEW            NONE
# 9718  08/01/2014 07:00:00 AM +0000  23:38   NORTHERN  ARREST, BOOKED
# 9719  08/01/2014 07:00:00 AM +0000  00:01    MISSION            NONE
#
#                            Address           X          Y  \
# 0          HYDE ST / CALIFORNIA ST -122.417393  37.790974
# 1         COLUMBUS AV / JACKSON ST -122.404418  37.796302
# 2          SUTTER ST / STOCKTON ST -122.406959  37.789435
# 3             16TH ST / MISSION ST -122.419672  37.765050
# 4          LARKIN ST / OFARRELL ST -122.417904  37.785167
# ...                            ...         ...        ...
# 9715    1100.0 Block of POTRERO AV -122.406497  37.754279
# 9716  1500.0 Block of BRODERICK ST -122.441458  37.784427
# 9717      400.0 Block of TUNNEL AV -122.401364  37.709748
# 9718            OAK ST / LAGUNA ST -122.425892  37.774599
# 9719    1000.0 Block of POTRERO AV -122.406657  37.756826
#
#                                    Location  Month  Day
# 0     (37.7909741243888, -122.417392830334)      8   31
# 1     (37.7963018736036, -122.404417620748)      8   31
# 2     (37.7894347630337, -122.406958660602)      8   31
# 3     (37.7650501214965, -122.419671780296)      8   31
# 4     (37.7851670875814, -122.417903977564)      8   31
# ...                                     ...    ...  ...
# 9715  (37.7542787119615, -122.406496573501)      8    1
# 9716  (37.7844267703853, -122.441458405736)      8    1
# 9717  (37.7097484169623, -122.401363713536)      8    1
# 9718  (37.7745985957044, -122.425891675136)      8    1
# 9719  (37.7568256145719, -122.406656623063)      8    1
#
# [9720 rows x 14 columns]

# %% [markdown]
# ### ¿Cuántos incidentes de delitos hubo en agosto?
#
# #### 9720
#
# ### ¿Cuántos bulglaries se informaron en agosto?
#
# #### 373

# %%
# code cell 17
# Possible code for the question: How many burglaries were reported in the month of August?
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimesB = AugustCrimes[AugustCrimes['Category'] == 'BURGLARY']
#len(AugustCrimesB)

AugustCrimesB['Category'].value_counts()
# Out:
# BURGLARY    373
# Name: Category, dtype: int64

# %%
# Code cell 18
Crime0704 = SF.query('Month == 7 and Day == 4')
Crime0704
# Out:
#        IncidntNum        Category  \
# 19087         NaN   LARCENY/THEFT
# 19088         NaN   LARCENY/THEFT
# 19089         NaN        BURGLARY
# 19090         NaN    NON-CRIMINAL
# 19091         NaN         ASSAULT
# ...           ...             ...
# 19423         NaN   LARCENY/THEFT
# 19424         NaN  OTHER OFFENSES
# 19425         NaN   LARCENY/THEFT
# 19426         NaN   LARCENY/THEFT
# 19427         NaN   LARCENY/THEFT
#
#                                                Descript DayOfWeek  \
# 19087                      GRAND THEFT FROM LOCKED AUTO    Friday
# 19088                      GRAND THEFT FROM LOCKED AUTO    Friday
# 19089  BURGLARY,RESIDENCE UNDER CONSTRT, FORCIBLE ENTRY    Friday
# 19090                                     LOST PROPERTY    Friday
# 19091                                           BATTERY    Friday
# ...                                                 ...       ...
# 19423                      GRAND THEFT FROM LOCKED AUTO    Friday
# 19424                         LOST/STOLEN LICENSE PLATE    Friday
# 19425                      GRAND THEFT FROM LOCKED AUTO    Friday
# 19426                      GRAND THEFT FROM LOCKED AUTO    Friday
# 19427                           PETTY THEFT OF PROPERTY    Friday
#
#                                Date   Time PdDistrict Resolution  \
# 19087  07/04/2014 07:00:00 AM +0000  22:30   SOUTHERN       NONE
# 19088  07/04/2014 07:00:00 AM +0000  18:15   SOUTHERN       NONE
# 19089  07/04/2014 07:00:00 AM +0000  00:50    TARAVAL       NONE
# 19090  07/04/2014 07:00:00 AM +0000  19:00       PARK       NONE
# 19091  07/04/2014 07:00:00 AM +0000  21:00   NORTHERN       NONE
# ...                             ...    ...        ...        ...
# 19423  07/04/2014 07:00:00 AM +0000  19:25   SOUTHERN       NONE
# 19424  07/04/2014 07:00:00 AM +0000  11:00  INGLESIDE       NONE
# 19425  07/04/2014 07:00:00 AM +0000  20:30   SOUTHERN       NONE
# 19426  07/04/2014 07:00:00 AM +0000  08:00   SOUTHERN       NONE
# 19427  07/04/2014 07:00:00 AM +0000  15:30   RICHMOND       NONE
#
#                                      Address           X          Y  \
# 19087                    8TH ST / MISSION ST -122.413161  37.777457
# 19088                 CLEMENTINA ST / 9TH ST -122.412174  37.774201
# 19089                0.0 Block of MENDOSA AV -122.466414  37.748011
# 19090                    CASTRO ST / 16TH ST -122.435318  37.764102
# 19091                1000.0 Block of POLK ST -122.419783  37.785894
# ...                                      ...         ...        ...
# 19423    THE EMBARCADEROSOUTH ST / BRYANT ST -122.388007  37.787103
# 19424               0.0 Block of FRATESSA CT -122.399762  37.716129
# 19425  THE EMBARCADEROSOUTH ST / HARRISON ST -122.388486  37.789573
# 19426                  11TH ST / HARRISON ST -122.412483  37.770631
# 19427               3900.0 Block of GEARY BL -122.461295  37.781181
#
#                                     Location  Month  Day
# 19087   (37.7774566612104, -122.41316085097)      7    4
# 19088  (37.7742011047558, -122.412173767284)      7    4
# 19089    (37.74801131976, -122.466413792313)      7    4
# 19090  (37.7641020287474, -122.435318423327)      7    4
# 19091  (37.7858942309362, -122.419782905411)      7    4
# ...                                      ...    ...  ...
# 19423  (37.7871027247862, -122.388007401911)      7    4
# 19424  (37.7161291670703, -122.399761873261)      7    4
# 19425  (37.7895727625927, -122.388485562387)      7    4
# 19426   (37.7706305911072, -122.41248326348)      7    4
# 19427  (37.7811812287207, -122.461294686397)      7    4
#
# [341 rows x 14 columns]

# %%
# Code cell 19
SF.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'Month',
#        'Day'],
#       dtype='object')

# %% [markdown]
# ## Parte 5: Presentación de datos
# ### Paso 1: Graficar el marco de datos de SF con las mismas variables X e Y

# %%
# Code cell 20
plt.plot(SF['X'],SF['Y'], 'ro')
plt.show()

# %%
# Code cell 21
pd_districts = np.unique(SF['PdDistrict'])
pd_districts_levels = dict(zip(pd_districts, range(len(pd_districts))))
pd_districts_levels
# Out:
# {'BAYVIEW': 0,
#  'CENTRAL': 1,
#  'INGLESIDE': 2,
#  'MISSION': 3,
#  'NORTHERN': 4,
#  'PARK': 5,
#  'RICHMOND': 6,
#  'SOUTHERN': 7,
#  'TARAVAL': 8,
#  'TENDERLOIN': 9}

# %%
# Code cell 22
SF['PdDistrictCode'] = SF['PdDistrict'].apply(lambda row: pd_districts_levels[row])

# %%
# Code cell 23
plt.scatter(SF['X'], SF['Y'], c=SF['PdDistrictCode'])
plt.show()

# %% [markdown]
# ### Paso 2: Agregar los paquetes de mapas para mejorar el gráfico

# %%
# Code cell 24
from matplotlib import colors
districts = np.unique(SF['PdDistrict'])
print(list(colors.cnames.values())[0:len(districts)])
# Out:
# ['#F0F8FF', '#FAEBD7', '#00FFFF', '#7FFFD4', '#F0FFFF', '#F5F5DC', '#FFE4C4', '#000000', '#FFEBCD', '#0000FF']

# %%
# Code cell 25
color_dict = dict(zip(districts, list(colors.cnames.values())[0:-1:len(districts)]))  
color_dict
# Out:
# {'BAYVIEW': '#F0F8FF',
#  'CENTRAL': '#8A2BE2',
#  'INGLESIDE': '#00FFFF',
#  'MISSION': '#FF8C00',
#  'NORTHERN': '#FF1493',
#  'PARK': '#F8F8FF',
#  'RICHMOND': '#4B0082',
#  'SOUTHERN': '#FAFAD2',
#  'TARAVAL': '#B0C4DE',
#  'TENDERLOIN': '#9370DB'}

# %%
# Code cell 26
#Create map
map_osm = folium.Map(location=[SF['Y'].mean(), SF['X'].mean()], zoom_start = 12)
plotEvery = 10
obs = list(zip( SF['Y'], SF['X'], SF['PdDistrict']))

for el in obs[0:-1:plotEvery]:
    
    folium.CircleMarker(el[0:2], color=color_dict[el[2]], fill_color=el[2],radius=1).add_to(map_osm)

# %%
# Code cell 27
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
